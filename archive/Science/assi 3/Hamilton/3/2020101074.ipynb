# %% [markdown]
# ### SCIENCE-2 ASSIGNMENT 2
# ### NAIMEESH NARAYAN TIWARI
# ### 2020101074
#
# - TASK 1 is in pdf

# %% [markdown]
# ### TASK 2

# %%
import numpy as np
import matplotlib.pyplot as plt

k = 2020101074 % 3 + 1
m = 2020101074 % 5 + 1

w_sq = k/m

print(k, m, w_sq)


dt = 0.0001
n = 200000

x_array = np.zeros(n)
momentum_array = np.zeros(n)

x_array[0] = 2020101074 % 7 + 1

for i in range(n-1):
    x_array[i+1] = x_array[i] + momentum_array[i]*dt/m
    momentum_array[i+1] = momentum_array[i] - k*x_array[i]*dt


# print(x_array.shape)
# print(momentum_array.shape)
plt.plot(x_array, 'r-', label='position')
plt.ylabel('position')
plt.show()

plt.plot(momentum_array, 'b-', label='velocity')
plt.ylabel('velocity')
plt.show()
# Out:
# 3 5 0.6

# %% [markdown]
# ### TASK 3

# %%
# plot the trajectory of the system in the phase space
plt.plot(momentum_array,x_array, 'r-')

# %% [markdown]
# ### TASK 4

# %%
const=0.01
point=np.zeros(1000)
m = x_array[0]
   
for i in range(1000):
    point[i]=m
    diff = -const*k*m
    m += diff


alpha = 0.5*k


print(m)
print("minimzed U in 1000 computations: ")
print(alpha*(m**2))



plt.plot(x_array,alpha*(x_array**2),label="1/2kx^2")
plt.scatter(point, alpha*(point**2),color='r', label="computed")
plt.xlabel("x")
plt.ylabel("U")
plt.show()
# Out:
# 3.54719870017206e-13
# minimzed U in 1000 computations:
# 1.8873927927753527e-25
